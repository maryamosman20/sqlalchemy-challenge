# %% [markdown]
# # Bonus: Temperature Analysis I

# %%
import pandas as pd
from datetime import datetime as dt
from sqlalchemy.orm import Session

# %%
# "tobs" is "temperature observations"
df = pd.read_csv('Resources/hawaii_measurements.csv')
df.head()
# Out:
#        station        date  prcp  tobs
# 0  USC00519397  2010-01-01  0.08    65
# 1  USC00519397  2010-01-02  0.00    63
# 2  USC00519397  2010-01-03  0.00    74
# 3  USC00519397  2010-01-04  0.00    76
# 4  USC00519397  2010-01-06   NaN    73

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19550 entries, 0 to 19549
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   station  19550 non-null  object
#  1   date     19550 non-null  object
#  2   prcp     18103 non-null  float64
#  3   tobs     19550 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 611.1+ KB

# %%
# Convert the date column format from string to datetime
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19550 entries, 0 to 19549
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   station  19550 non-null  object
#  1   date     19550 non-null  datetime64[ns]
#  2   prcp     18103 non-null  float64
#  3   tobs     19550 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 611.1+ KB

# %%
# Set the date column as the DataFrame index
df.set_index('date')
# Out:
#                 station  prcp  tobs
# date
# 2010-01-01  USC00519397  0.08    65
# 2010-01-02  USC00519397  0.00    63
# 2010-01-03  USC00519397  0.00    74
# 2010-01-04  USC00519397  0.00    76
# 2010-01-06  USC00519397   NaN    73
# ...                 ...   ...   ...
# 2017-08-19  USC00516128  0.09    71
# 2017-08-20  USC00516128   NaN    78
# 2017-08-21  USC00516128  0.56    76
# 2017-08-22  USC00516128  0.50    76
# 2017-08-23  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %%
df.set_index('tobs')
# Out:
#           station       date  prcp
# tobs
# 65    USC00519397 2010-01-01  0.08
# 63    USC00519397 2010-01-02  0.00
# 74    USC00519397 2010-01-03  0.00
# 76    USC00519397 2010-01-04  0.00
# 73    USC00519397 2010-01-06   NaN
# ...           ...        ...   ...
# 71    USC00516128 2017-08-19  0.09
# 78    USC00516128 2017-08-20   NaN
# 76    USC00516128 2017-08-21  0.56
# 76    USC00516128 2017-08-22  0.50
# 76    USC00516128 2017-08-23  0.45
#
# [19550 rows x 3 columns]

# %%
# Drop the date column
df.drop(['date'], axis = 1)
# Out:
#            station  prcp  tobs
# 0      USC00519397  0.08    65
# 1      USC00519397  0.00    63
# 2      USC00519397  0.00    74
# 3      USC00519397  0.00    76
# 4      USC00519397   NaN    73
# ...            ...   ...   ...
# 19545  USC00516128  0.09    71
# 19546  USC00516128   NaN    78
# 19547  USC00516128  0.56    76
# 19548  USC00516128  0.50    76
# 19549  USC00516128  0.45    76
#
# [19550 rows x 3 columns]

# %% [markdown]
# ### Compare June and December data across all years

# %%
from scipy import stats

# %%
# Filter data for desired months
filtered_df = df.query("date >= '2010-06-01' and date < '2017-12-01'")
filtered_df
# Out:
#            station        date  prcp  tobs
# 133    USC00519397  2010-06-01  0.00    78
# 134    USC00519397  2010-06-02  0.01    76
# 135    USC00519397  2010-06-03  0.00    78
# 136    USC00519397  2010-06-04  0.00    76
# 137    USC00519397  2010-06-05  0.00    77
# ...            ...         ...   ...   ...
# 19545  USC00516128  2017-08-19  0.09    71
# 19546  USC00516128  2017-08-20   NaN    78
# 19547  USC00516128  2017-08-21  0.56    76
# 19548  USC00516128  2017-08-22  0.50    76
# 19549  USC00516128  2017-08-23  0.45    76
#
# [18472 rows x 4 columns]

# %%
# Identify the average temperature for June

# %%
# Identify the average temperature for December

# %%
# Create collections of temperature data

# %%
# Run paired t-test

# %% [markdown]
# ### Analysis
